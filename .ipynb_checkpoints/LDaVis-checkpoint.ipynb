# %%
# -*- coding: utf-8 -*-
import unicodecsv
import argparse
import pyLDAvis.gensim

from lib.utils import *

# %%
class data:
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)
args = data()
args.filename = "paultan.csv"
args.stemmer = "lemma"
args.dictionary = "automotive"
args.num_iter = 20
args.num_top_words = 8
args.num_topics = 10
args.model = "lda"


dir = os.getcwd()
model_dir = os.path.join(dir, 'models/')
dataset_dir = os.path.join(dir, 'datasets/')
dictionary_dir = os.path.join(dir, 'dictionaries/')
executable_dir = os.path.join(dir, 'executables/')
my_timeslices = [500,500,500,500,500, 346]

model_filename = os.path.join(model_dir, get_model_with_arguments_filename(args))
is_english_word = load_from_dictionary(args.dictionary)

print model_filename
# Out:
# /Users/Hii/Projects/news_scraper/models/paultan_lemma_20_8_10_lda_automotive

# %%
try:
  dataset_filepath = os.path.join(dataset_dir, args.filename)
  f = open(dataset_filepath)
  reader = unicodecsv.reader(f, encoding='utf-8')

  identifiers = reader.next()
  contents_idx = identifiers.index("contents")
  title_idx = identifiers.index("title")

  contents, titles = zip(*[(row[contents_idx], row[title_idx]) for row in reader])

  tokenizer = RegexpTokenizer(r'\w+')
  print "Tokenizing ..."

  texts = [ process_tokens(tokenizer.tokenize(word.lower()), args.stemmer,is_english_word) for word in contents ]
  print "[DEBUG] Length of Texts : {}".format(len(texts))

  dictionary = corpora.Dictionary(texts)
  corpus = [dictionary.doc2bow(text) for text in texts]

  ldamodel = models.LdaModel.load(model_filename)
except IOError:
  ldamodel = generate_model(args.model, corpus, dictionary, args.num_topics, args.num_iter)
  ldamodel.save(model_filename)
if args.model =="lda":
  pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
# Out:
# Tokenizing ...
# [DEBUG] Length of Texts : 2846

# %%
show_topics(args.model, ldamodel, args.num_topics, args.num_top_words)
# Out:
# Topic #0 : toyota coupe safety car vehicle new test type
# Topic #1 : ford vehicle car technology driver new development make
# Topic #2 : new honda car design mazda model sedan hyundai
# Topic #3 : proton volkswagen fuel car new year engine test
# Topic #4 : race highway racing porsche suzuki formula year car
# Topic #5 : year nissan service new increase price mitsubishi industry
# Topic #6 : bmw audi new drive car model feature fiat
# Topic #7 : class car ferrari new convertible driver year course
# Topic #8 : car control wheel speed feature power engine drive
# Topic #9 : new engine speed transmission torque automatic kia manual

# %%
pyLDAvis.enable_notebook()
pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 8      24.044792        1       1 -0.189567 -0.002087
# 9      15.017464        1       2 -0.223973 -0.037763
# 2      12.699580        1       3 -0.111232  0.010569
# 5       9.314371        1       4  0.137348  0.029531
# 1       8.545571        1       5  0.158929  0.017915
# 3       7.300512        1       6  0.084948 -0.035747
# 6       6.390742        1       7 -0.164452 -0.004518
# 7       5.925905        1       8  0.036051  0.030920
# 0       5.385514        1       9  0.113558  0.267772
# 4       5.375549        1      10  0.158391 -0.276592, topic_info=     Category         Freq           Term        Total  loglift  logprob
# term
# 355   Default  1307.000000            bmw  1307.000000  30.0000  30.0000
# 437   Default  1081.000000         toyota  1081.000000  29.0000  29.0000
# 252   Default   980.000000          class   980.000000  28.0000  28.0000
# 338   Default   869.000000         proton   869.000000  27.0000  27.0000
# 373   Default   839.000000           audi   839.000000  26.0000  26.0000
# 290   Default   998.000000          honda   998.000000  25.0000  25.0000
# 463   Default   711.000000     volkswagen   711.000000  24.0000  24.0000
# 436   Default   718.000000         nissan   718.000000  23.0000  23.0000
# 486   Default   674.000000          coupe   674.000000  22.0000  22.0000
# 168   Default   859.000000         safety   859.000000  21.0000  21.0000
# 206   Default   614.000000        service   614.000000  20.0000  20.0000
# 500   Default   634.000000           ford   634.000000  19.0000  19.0000
# 295   Default  4988.000000            new  4988.000000  18.0000  18.0000
# 156   Default  1953.000000           year  1953.000000  17.0000  17.0000
# 282   Default   879.000000           fuel   879.000000  16.0000  16.0000
# 317   Default   634.000000          mazda   634.000000  15.0000  15.0000
# 351   Default  2340.000000         engine  2340.000000  14.0000  14.0000
# 26    Default   420.000000           race   420.000000  13.0000  13.0000
# 415   Default  1686.000000          speed  1686.000000  12.0000  12.0000
# 27    Default  3580.000000            car  3580.000000  11.0000  11.0000
# 78    Default  1352.000000        vehicle  1352.000000  10.0000  10.0000
# 173   Default   439.000000        highway   439.000000   9.0000   9.0000
# 37    Default  1180.000000         design  1180.000000   8.0000   8.0000
# 346   Default   332.000000        porsche   332.000000   7.0000   7.0000
# 46    Default   291.000000         racing   291.000000   6.0000   6.0000
# 25    Default   737.000000   transmission   737.000000   5.0000   5.0000
# 493   Default   275.000000         suzuki   275.000000   4.0000   4.0000
# 177   Default   359.000000        hyundai   359.000000   3.0000   3.0000
# 231   Default   845.000000         torque   845.000000   2.0000   2.0000
# 251   Default   607.000000          sedan   607.000000   1.0000   1.0000
# ...       ...          ...            ...          ...      ...      ...
# 173   Topic10   307.995599        highway   439.630693   2.5675  -2.6324
# 258   Topic10    17.337085          crowd    24.909408   2.5609  -5.5096
# 192   Topic10     1.942280    contingency     2.864340   2.5348  -7.6986
# 52    Topic10     1.942210          spiel     2.864342   2.5348  -7.6986
# 39    Topic10     5.287088       rigorous     7.808281   2.5334  -6.6972
# 204   Topic10     5.632402    arbitration     8.549034   2.5060  -6.6339
# 93    Topic10     5.596337        fulfill     8.497443   2.5057  -6.6403
# 383   Topic10    15.891429       entitled    24.667356   2.4836  -5.5967
# 90    Topic10    61.306467      challenge    97.499545   2.4593  -4.2466
# 42    Topic10    15.497436     sequential    27.825350   2.3380  -5.6218
# 445   Topic10    40.931870           deal    95.236882   2.0789  -4.6505
# 531   Topic10    88.307826          event   329.031097   1.6080  -3.8816
# 205   Topic10    37.287290     management   122.138904   1.7368  -4.7438
# 340   Topic10    14.826119           pole    36.057030   2.0346  -5.6661
# 503   Topic10    35.196690   construction   153.010391   1.4538  -4.8015
# 156   Topic10   153.044458           year  1953.051648   0.3769  -3.3317
# 512   Topic10    25.144318          limit    92.870102   1.6167  -5.1378
# 27    Topic10   151.431249            car  3580.256432  -0.2397  -3.3423
# 389   Topic10    73.743543         driver   848.580037   0.4803  -4.0619
# 260   Topic10    37.342955        ferrari   211.926568   1.1872  -4.7423
# 151   Topic10    31.120657         energy   148.258334   1.3622  -4.9246
# 461   Topic10    69.119118          power  1143.433291   0.1174  -4.1266
# 122   Topic10    57.311865           make   734.292410   0.3729  -4.3139
# 55    Topic10    32.599716      technical   192.255111   1.1488  -4.8781
# 36    Topic10    39.830698           cost   340.932737   0.7763  -4.6778
# 351   Topic10    73.397315         engine  2340.219760  -0.5388  -4.0666
# 43    Topic10    34.222751  international   254.316961   0.9176  -4.8296
# 415   Topic10    55.363880          speed  1686.478753  -0.4932  -4.3485
# 295   Topic10    70.780227            new  4988.020272  -1.3319  -4.1029
# 490   Topic10    35.285150          start   507.046889   0.2582  -4.7990
#
# [595 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 296       5  0.928624         aaa
# 341       7  0.989262      abarth
# 183       1  0.308277   accessory
# 183       4  0.264237   accessory
# 183       7  0.110099   accessory
# 183       9  0.308277   accessory
# 325       4  0.156845    accident
# 325       5  0.679660    accident
# 325       8  0.117634    accident
# 325      10  0.039211    accident
# 60        4  0.026122      action
# 60        5  0.457127      action
# 60        6  0.124077      action
# 60        8  0.084895      action
# 60        9  0.182851      action
# 60       10  0.117547      action
# 492       2  0.614598    actuator
# 492       8  0.204866    actuator
# 23        1  0.814406    adaptive
# 23        2  0.133394    adaptive
# 23        7  0.049145    adaptive
# 166       5  0.408781    adhesion
# 166       7  0.408781    adhesion
# 4         1  0.940429  adjustment
# 4         6  0.024748  adjustment
# 4         7  0.024748  adjustment
# 390       1  0.079124       alert
# 390       2  0.720908       alert
# 390       5  0.193414       alert
# 416       5  0.982333   alignment
# ...     ...       ...         ...
# 337       5  0.033821        wall
# 337       6  0.169107        wall
# 337       8  0.541142        wall
# 479       1  0.155113    warranty
# 479       2  0.005966    warranty
# 479       4  0.841190    warranty
# 148       1  0.779045       wheel
# 148       2  0.120554       wheel
# 148       3  0.057745       wheel
# 148       7  0.028366       wheel
# 148       8  0.005065       wheel
# 148      10  0.009118       wheel
# 279       3  0.095317      winner
# 279       8  0.071487      winner
# 279      10  0.810191      winner
# 353       6  0.705160    withhold
# 156       1  0.037889        year
# 156       2  0.039425        year
# 156       3  0.164870        year
# 156       4  0.438288        year
# 156       5  0.081923        year
# 156       6  0.082947        year
# 156       7  0.006656        year
# 156       8  0.058882        year
# 156       9  0.011264        year
# 156      10  0.078339        year
# 227       5  0.856591       youth
# 227       8  0.085659       youth
# 470       6  0.745545         zip
# 10        9  0.930704       zotye
#
# [1303 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[9, 10, 3, 6, 2, 4, 7, 8, 1, 5])
