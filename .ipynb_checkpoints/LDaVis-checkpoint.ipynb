# %%
class data:
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)
args = data()
args.filename = "soya_dataset_year.csv"
args.stemmer = "lemma"

# %%
# -*- coding: utf-8 -*-
import numpy as np
import lda
import lda.datasets
import csv
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
from gensim import corpora, models

from stemming.porter2 import stem
from nltk.stem import *
import unicodecsv
import re
import pyLDAvis.gensim
import gensim

_digits = re.compile('\d')
def contains_digits(d):
    return bool(_digits.search(d))

def process_tokens(tokens,stemmer):
  tokens = [i for i in tokens if not i in en_stop and not contains_digits(i)]
  if stemmer == 'porter':
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(i) for i in tokens]
  elif stemmer == 'porter2':
    tokens = [stem(i) for i in tokens]
  elif stemmer == 'lemma':
    lemmatiser = WordNetLemmatizer()
    tokens = [lemmatiser.lemmatize(i) for i in tokens]
  return tokens


if args.filename == "sample":
  X = lda.datasets.load_reuters()
  dictionary = lda.datasets.load_reuters_vocab()
  titles = lda.datasets.load_reuters_titles()
else:
  f = open(args.filename)
  reader = unicodecsv.reader(f, encoding='utf-8')
  # csv_length = sum(1 for row in reader)
  # f.seek(0) #reset reader position
  identifiers = reader.next()
  contents_idx = identifiers.index("contents")
  title_idx = identifiers.index("title")

  contents = [ row[contents_idx] for row in reader if row[contents_idx] ]

  f.seek(0)
  reader.next()
  titles = [ row[title_idx] for row in reader if row[contents_idx] ]



  texts = list()
  tokenizer = RegexpTokenizer(r'\w+')
  en_stop = get_stop_words('en')
  for idx,i in enumerate(contents):
#     if not idx % 10:
#       print "INFO: Tokenizing articles <{}> ".format(idx)
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)
    texts.append(process_tokens(tokens, args.stemmer))
    # print idx
    # add tokens to list

  print "[DEBUG] Length of Texts : {}".format(len(texts))
  dictionary = corpora.Dictionary(texts)
  corpus = [dictionary.doc2bow(text) for text in texts]
# Out:
# INFO: Tokenizing articles <0>
# INFO: Tokenizing articles <10>
# INFO: Tokenizing articles <20>
# INFO: Tokenizing articles <30>
# INFO: Tokenizing articles <40>
# INFO: Tokenizing articles <50>
# INFO: Tokenizing articles <60>
# INFO: Tokenizing articles <70>
# INFO: Tokenizing articles <80>
# INFO: Tokenizing articles <90>
# INFO: Tokenizing articles <100>
# INFO: Tokenizing articles <110>
# INFO: Tokenizing articles <120>
# INFO: Tokenizing articles <130>
# INFO: Tokenizing articles <140>
# INFO: Tokenizing articles <150>
# INFO: Tokenizing articles <160>
# INFO: Tokenizing articles <170>
# INFO: Tokenizing articles <180>
# INFO: Tokenizing articles <190>
# INFO: Tokenizing articles <200>
# INFO: Tokenizing articles <210>
# INFO: Tokenizing articles <220>
# INFO: Tokenizing articles <230>
# INFO: Tokenizing articles <240>
# INFO: Tokenizing articles <250>
# INFO: Tokenizing articles <260>
# INFO: Tokenizing articles <270>
# INFO: Tokenizing articles <280>
# INFO: Tokenizing articles <290>
# INFO: Tokenizing articles <300>
# INFO: Tokenizing articles <310>
# INFO: Tokenizing articles <320>
# INFO: Tokenizing articles <330>
# INFO: Tokenizing articles <340>
# INFO: Tokenizing articles <350>
# INFO: Tokenizing articles <360>
# INFO: Tokenizing articles <370>
# INFO: Tokenizing articles <380>
# INFO: Tokenizing articles <390>
# INFO: Tokenizing articles <400>
# INFO: Tokenizing articles <410>
# INFO: Tokenizing articles <420>
# INFO: Tokenizing articles <430>
# INFO: Tokenizing articles <440>
# INFO: Tokenizing articles <450>
# INFO: Tokenizing articles <460>
# INFO: Tokenizing articles <470>
# INFO: Tokenizing articles <480>
# INFO: Tokenizing articles <490>
# INFO: Tokenizing articles <500>
# INFO: Tokenizing articles <510>
# INFO: Tokenizing articles <520>
# INFO: Tokenizing articles <530>
# INFO: Tokenizing articles <540>
# INFO: Tokenizing articles <550>
# INFO: Tokenizing articles <560>
# INFO: Tokenizing articles <570>
# INFO: Tokenizing articles <580>
# INFO: Tokenizing articles <590>
# INFO: Tokenizing articles <600>
# INFO: Tokenizing articles <610>
# INFO: Tokenizing articles <620>
# INFO: Tokenizing articles <630>
# INFO: Tokenizing articles <640>
# INFO: Tokenizing articles <650>
# INFO: Tokenizing articles <660>
# INFO: Tokenizing articles <670>
# INFO: Tokenizing articles <680>
# INFO: Tokenizing articles <690>
# INFO: Tokenizing articles <700>
# INFO: Tokenizing articles <710>
# INFO: Tokenizing articles <720>
# INFO: Tokenizing articles <730>
# INFO: Tokenizing articles <740>
# INFO: Tokenizing articles <750>
# INFO: Tokenizing articles <760>
# INFO: Tokenizing articles <770>
# INFO: Tokenizing articles <780>
# INFO: Tokenizing articles <790>
# INFO: Tokenizing articles <800>
# INFO: Tokenizing articles <810>
# INFO: Tokenizing articles <820>
# INFO: Tokenizing articles <830>
# INFO: Tokenizing articles <840>
# INFO: Tokenizing articles <850>
# INFO: Tokenizing articles <860>
# INFO: Tokenizing articles <870>
# INFO: Tokenizing articles <880>
# INFO: Tokenizing articles <890>
# INFO: Tokenizing articles <900>
# INFO: Tokenizing articles <910>
# INFO: Tokenizing articles <920>
# INFO: Tokenizing articles <930>
# INFO: Tokenizing articles <940>
# INFO: Tokenizing articles <950>
# INFO: Tokenizing articles <960>
# INFO: Tokenizing articles <970>
# INFO: Tokenizing articles <980>
# INFO: Tokenizing articles <990>
# INFO: Tokenizing articles <1000>
# INFO: Tokenizing articles <1010>
# INFO: Tokenizing articles <1020>
# INFO: Tokenizing articles <1030>
# INFO: Tokenizing articles <1040>
# INFO: Tokenizing articles <1050>
# INFO: Tokenizing articles <1060>
# INFO: Tokenizing articles <1070>
# INFO: Tokenizing articles <1080>
# INFO: Tokenizing articles <1090>
# INFO: Tokenizing articles <1100>
# INFO: Tokenizing articles <1110>
# INFO: Tokenizing articles <1120>
# INFO: Tokenizing articles <1130>
# INFO: Tokenizing articles <1140>
# INFO: Tokenizing articles <1150>
# INFO: Tokenizing articles <1160>
# INFO: Tokenizing articles <1170>
# INFO: Tokenizing articles <1180>
# INFO: Tokenizing articles <1190>
# INFO: Tokenizing articles <1200>
# INFO: Tokenizing articles <1210>
# INFO: Tokenizing articles <1220>
# INFO: Tokenizing articles <1230>
# INFO: Tokenizing articles <1240>
# INFO: Tokenizing articles <1250>
# INFO: Tokenizing articles <1260>
# INFO: Tokenizing articles <1270>
# INFO: Tokenizing articles <1280>
# INFO: Tokenizing articles <1290>
# INFO: Tokenizing articles <1300>
# INFO: Tokenizing articles <1310>
# INFO: Tokenizing articles <1320>
# INFO: Tokenizing articles <1330>
# INFO: Tokenizing articles <1340>
# INFO: Tokenizing articles <1350>
# INFO: Tokenizing articles <1360>
# INFO: Tokenizing articles <1370>
# INFO: Tokenizing articles <1380>
# INFO: Tokenizing articles <1390>
# INFO: Tokenizing articles <1400>
# INFO: Tokenizing articles <1410>
# INFO: Tokenizing articles <1420>
# INFO: Tokenizing articles <1430>
# INFO: Tokenizing articles <1440>
# INFO: Tokenizing articles <1450>
# INFO: Tokenizing articles <1460>
# INFO: Tokenizing articles <1470>
# INFO: Tokenizing articles <1480>
# INFO: Tokenizing articles <1490>
# INFO: Tokenizing articles <1500>
# INFO: Tokenizing articles <1510>
# INFO: Tokenizing articles <1520>
# INFO: Tokenizing articles <1530>
# INFO: Tokenizing articles <1540>
# INFO: Tokenizing articles <1550>
# INFO: Tokenizing articles <1560>
# INFO: Tokenizing articles <1570>
# INFO: Tokenizing articles <1580>
# INFO: Tokenizing articles <1590>
# INFO: Tokenizing articles <1600>
# INFO: Tokenizing articles <1610>
# INFO: Tokenizing articles <1620>
# INFO: Tokenizing articles <1630>
# INFO: Tokenizing articles <1640>
# INFO: Tokenizing articles <1650>
# INFO: Tokenizing articles <1660>
# INFO: Tokenizing articles <1670>
# INFO: Tokenizing articles <1680>
# INFO: Tokenizing articles <1690>
# INFO: Tokenizing articles <1700>
# INFO: Tokenizing articles <1710>
# INFO: Tokenizing articles <1720>
# INFO: Tokenizing articles <1730>
# INFO: Tokenizing articles <1740>
# INFO: Tokenizing articles <1750>
# INFO: Tokenizing articles <1760>
# INFO: Tokenizing articles <1770>
# INFO: Tokenizing articles <1780>
# INFO: Tokenizing articles <1790>
# INFO: Tokenizing articles <1800>
# INFO: Tokenizing articles <1810>
# [DEBUG] Length of Texts : 1812

# %%
pyLDAvis.enable_notebook()
model_filename = args.filename.split('.')[0] + '.model'
try:
  ldamodel = models.LdaModel.load(model_filename)
except IOError:
  ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=10, id2word = dictionary, passes=5)
  ldamodel.save(model_filename)
    
pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 2      49.766047        1       1  0.113033  0.066129
# 0      33.917076        1       2  0.021086 -0.105306
# 1      16.316877        1       3 -0.134119  0.039177, topic_info=      Category         Freq        Term  Total  loglift  logprob
# 1950   Default   809.000000        plan    809  30.0000  30.0000
# 4876   Default   946.000000       month    946  29.0000  29.0000
# 947    Default   610.000000        data    610  28.0000  28.0000
# 4173   Default  2540.000000         can   2540  27.0000  27.0000
# 5796   Default  1740.000000      camera   1740  26.0000  26.0000
# 10074  Default   440.000000        maxi    440  25.0000  25.0000
# 9978   Default   548.000000        free    548  24.0000  24.0000
# 10614  Default   880.000000      iphone    880  23.0000  23.0000
# 9134   Default  2230.000000      galaxy   2230  22.0000  22.0000
# 10134  Default   881.000000       watch    881  21.0000  21.0000
# 4759   Default  1079.000000   processor   1079  20.0000  20.0000
# 1050   Default   374.000000    internet    374  19.0000  19.0000
# 10057  Default  1025.000000         ram   1025  18.0000  18.0000
# 5279   Default   677.000000      mobile    677  17.0000  17.0000
# 6614   Default   445.000000        call    445  16.0000  16.0000
# 12221  Default   869.000000       apple    869  15.0000  15.0000
# 6813   Default   290.000000        digi    290  14.0000  14.0000
# 1483   Default   288.000000      celcom    288  13.0000  13.0000
# 5894   Default   967.000000       front    967  12.0000  12.0000
# 7754   Default  2317.000000         get   2317  11.0000  11.0000
# 6450   Default  1295.000000     display   1295  10.0000  10.0000
# 711    Default   478.000000       offer    478   9.0000   9.0000
# 309    Default   338.000000     service    338   8.0000   8.0000
# 10363  Default   727.000000        core    727   7.0000   7.0000
# 11947  Default  1049.000000        edge   1049   6.0000   6.0000
# 4838   Default  1021.000000     storage   1021   5.0000   5.0000
# 4205   Default   628.000000  snapdragon    628   4.0000   4.0000
# 6643   Default   639.000000        spec    639   3.0000   3.0000
# 7616   Default   963.000000       first    963   2.0000   2.0000
# 4437   Default   390.000000    offering    390   1.0000   1.0000
# ...        ...          ...         ...    ...      ...      ...
# 964     Topic3   215.013549          sm    268   1.5088  -5.5495
# 6614    Topic3   332.315274        call    445   1.4391  -5.1121
# 2531    Topic3   196.863256    customer    248   1.4987  -5.6372
# 309     Topic3   250.399120     service    338   1.4322  -5.3941
# 3481    Topic3   209.417406     network    276   1.4556  -5.5733
# 5477    Topic3   179.739420         gst    248   1.4132  -5.7227
# 10614   Topic3   473.858540      iphone    880   1.1261  -4.7432
# 5630    Topic3    97.654215        uber    113   1.5834  -6.3385
# 5279    Topic3   363.790059      mobile    677   1.1245  -5.0071
# 823     Topic3   120.460375        sign    151   1.5061  -6.1259
# 711     Topic3   267.897793       offer    478   1.1661  -5.3136
# 4437    Topic3   229.553404    offering    390   1.2135  -5.4697
# 4173    Topic3   708.142341         can   2540   0.4865  -4.3229
# 4128    Topic3   206.449124       extra    356   1.1996  -5.5748
# 7754    Topic3   476.788526         get   2317   0.1890  -4.7122
# 7616    Topic3   312.669954       first    963   0.6363  -5.1430
# 12663   Topic3   540.391214        will   3749  -0.1627  -4.5828
# 1284    Topic3   619.280864           s   5607  -0.4267  -4.4442
# 10338   Topic3   294.744382    malaysia    992   0.5500  -5.1996
# 9134    Topic3   395.715890      galaxy   2230   0.0435  -4.8961
# 6029    Topic3   238.426516        need    612   0.8141  -5.4184
# 8128    Topic3   272.514791           u    934   0.5315  -5.2783
# 6563    Topic3   344.904928         new   2000   0.0146  -5.0338
# 262     Topic3   272.276915          re   1143   0.3325  -5.2754
# 11947   Topic3   252.985523        edge   1049   0.3459  -5.3478
# 1936    Topic3   252.722426        also   1963  -0.2741  -5.3412
# 2236    Topic3   252.943989           t   2047  -0.3156  -5.3407
# 7098    Topic3   230.182658        just   1265   0.0676  -5.4388
# 9841    Topic3   233.477663       phone   1679  -0.1978  -5.4212
# 4274    Topic3   226.899463         now   1069   0.2194  -5.4555
#
# [306 rows x 6 columns], token_table=       Topic      Freq        Term
# term
# 11789      1  0.020408    activity
# 11789      2  0.959184    activity
# 11789      3  0.020408    activity
# 7603       1  0.027778     advance
# 7603       2  0.027778     advance
# 7603       3  0.958333     advance
# 3310       1  1.000000         akm
# 2598       1  0.105691       allow
# 2598       2  0.845528       allow
# 2598       3  0.040650       allow
# 1936       1  0.667855        also
# 1936       2  0.203260        also
# 1936       3  0.128884        also
# 2984       1  0.520499     android
# 2984       2  0.455437     android
# 2984       3  0.024064     android
# 7211       1  1.000000        apac
# 12225      1  0.051002         app
# 12225      2  0.854281         app
# 12225      3  0.094718         app
# 12221      1  0.039125       apple
# 12221      2  0.878021       apple
# 12221      3  0.084005       apple
# 8174       3  0.979167  applicable
# 12849      1  0.116438        apps
# 12849      2  0.842466        apps
# 12849      3  0.044521        apps
# 8895       3  1.000000    asiasoft
# 1962       1  0.986799        asus
# 1962       2  0.006601        asus
# ...      ...       ...         ...
# 10134      2  0.944381       watch
# 10134      3  0.024972       watch
# 3948       1  0.281659         way
# 3948       2  0.615721         way
# 3948       3  0.100437         way
# 10182      1  0.022472        wear
# 10182      2  0.977528        wear
# 2176       1  0.039062    wearable
# 2176       2  0.960938    wearable
# 2176       3  0.007812    wearable
# 6288       1  0.571429        well
# 6288       2  0.347911        well
# 6288       3  0.079689        well
# 12663      1  0.578288        will
# 12663      2  0.277407        will
# 12663      3  0.144038        will
# 3350       1  0.193443        work
# 3350       2  0.763934        work
# 3350       3  0.045902        work
# 12316      1  0.051724       wrist
# 12316      2  0.931034       wrist
# 2916       1  1.000000         wth
# 6671       3  0.976190        xpax
# 9656       1  0.969811      xperia
# 9656       2  0.016981      xperia
# 9656       3  0.013208      xperia
# 12360      1  1.000000        ybut
# 9642       1  0.993921     zenfone
# 9642       3  0.006079     zenfone
# 5686       3  0.979167  zerolution
#
# [514 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 1, 2])
